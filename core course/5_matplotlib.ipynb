# %% [markdown]
# # matplotlib

# %% [markdown]
# ## Basic graphs. Format.

# %% [markdown]
# Matplotlib is the most widely used python library for plotting data. It has a wide number of plot types, in 2 and 3 dimensions and allows to customize many details of the plots.

# %% [markdown]
# We will first show the general syntax with simple examples, and show how to display the graphs in a jupyter notebook and/or save them to files.

# %% [markdown]
# There are different ways to create a graph using matplotlib. This notebook shows one particular method, one that is very flexible and thus makes it possible to refine the results more. The method is based on the use of the function `subplots` from the `pyplot` submodule.

# %% [markdown]
# ### Matplotlib and pyplot

# %% [markdown]
# `pyplot` is a submodule of matplotlib, the one that we use in most cases to generate the graphs. It is a common practice to import pyplot with the following line:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Thereafter we will use `plt.` to gain access to many functions and methods inside pyplot.

# %% [markdown]
# The most general program that we will use to generate a plot has the following form:

# %% [raw]
# fig, ax = plt.subplots() # Create a figure and axis using plt.subplots
#
# ax.bar( list_of_data ) # Plot some data in the axis
#
# plt.show( fig ) # Show the figure in the screen
#
# plt.close( fig ) # Close the figure

# %% [markdown]
# It is often useful to visualize a general structure on that code:
# 1. First create the figure
# 2. Then plot, modify, change format, plot again, etc
# 3. Show, save, close

# %% [raw]
# #---------------------------------------------------------------------
# # Part 1: Create a figure and axis using plt.subplots
# fig, ax = plt.subplots()
# #---------------------------------------------------------------------
#
# # Part 2: Plot, modify, plot again, include text, etc.
# ax.plot( list_of_data )
#
# #---------------------------------------------------------------------
# # Part 3: Show, save to file, and close
# plt.show( fig )
# plt.close( fig )
# #---------------------------------------------------------------------

# %% [markdown]
# A reduced version of the same code, that works in most cases is shown below. It is however good to know which commands to try if it does _not_ work.

# %% [markdown]
# Reduced version:

# %% [raw]
# fig, ax = plt.subplots()
# ax.plot( list_of_data );

# %% [markdown]
# ### Graphs using `plt.subplots`

# %% [markdown]
# With matplotlib we always plot ___data___, which means that we need a list, array, series of numbers to plot.
#
# In this example, we will use the following lists of numbers to generate plots:

# %%
list1 = [ 1, 2, 4, 5, 7, 8, 9 ]
list2 = [ 0, 3, 3, 5, 6, 8, 6 ]
list3 = [ 0, 3, 4, 0, 1, 3, 2 ]

# %%
fig, ax = plt.subplots() # Create a figure and axis using plt.subplots

ax.plot( list1 ) # Plot some data in the axis

plt.show( fig ) # Show the figure in the screen

plt.close( fig ) # Close the figure

# %%
fig, ax = plt.subplots() # Create a figure and axis using plt.subplots

ax.plot( list2 ) # Plot some data in the axis

plt.show( fig ) # Show the figure in the screen

plt.close( fig ) # Close the figure

# %%
fig, ax = plt.subplots() # Create a figure and axis using plt.subplots

ax.plot( list3 ) # Plot some data in the axis

plt.show( fig ) # Show the figure in the screen

plt.close( fig ) # Close the figure

# %% [markdown]
# It is useful to visualize the previous piece of code as composed of three parts:

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( list3 )

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# The most work will be on part 2. The first thing that we can test is to plot all three lists of data on the same axis:

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( list1 )
ax.plot( list2 )
ax.plot( list3 )

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# Note that each call to `ax.plot()` line adds a new series to the graph.

# %% [markdown]
# Also notice that each element in the series is posotioned in the position that it has in the array. For example, with `list1`:

# %%
print( list1 )
# Out:
# [1, 2, 4, 5, 7, 8, 9]

# %% [markdown]
# This happens because there is no concrete specification of the position of the values on the x axis, and therefore `matplotlib` puts them one after the other, in ther position on the list.

# %% [markdown]
# We can specify the position on the `x` axis by sending two values to `.plot()`, first the `x` positions and then the `y` values:

# %% [markdown]
# If we use the values on `list1` as `x` coordinates, we get the following graph:

# %%
list1
# Out:
# [1, 2, 4, 5, 7, 8, 9]

# %%
list2
# Out:
# [0, 3, 3, 5, 6, 8, 6]

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( list1, list2 )
ax.plot( list1, list3 )

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# In other words, when we send two series of values to `ax.plot()`, each value in the first one defines where the corresponding value in the second will be positioned.

# %% [markdown]
# ### Format

# %% [markdown]
# We will modify the same graphic to show some ways to make it look better, namely:
#
# * change the line's width, style and color
# * add markers for the data points
# * add a legend
# * set labels for both axis, and a title

# %% [markdown]
# #### Line width, color and style

# %% [markdown]
# Each call to `ax.plot` plots a series of data. We can add parameters to that series to format it, just after the data parameters.
#
# Some commonly used format parameters are:
# * `linewidth` → takes numeric values, default is 1
# * `linestyle` → defines for example dashed lines, takes values like: '-', '--', '-.'
# * `color` → it is possible to specify colors by name ('red', 'black'), or abbreviations
#
# For more detailed information check `ax.plot?`

# %%
plt.plot?

# %%
ax.annotate?

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( list1, list2, linewidth=5, linestyle='-.', color='black' )
ax.plot( list1, list3, linewidth=2, linestyle='--', color='red', marker='o' )

ax.text( 4.5, 7.9, "Maximum point →", fontsize=12 )
ax.text( 1, 5, 'hello world!'  )

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# #### Markers

# %% [markdown]
# We can add markers to each point in the data series. A marker can be a circle, a square or many other symbols that tell us where each data point is located. They can be combined with lines, or used insted of them.

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( list1, list2, color='blue', marker='o', 
         markersize=15, markerfacecolor='magenta', 
         markeredgecolor='blue' ) #circle markers

ax.plot( list1, list3, marker='s' ) # square markers

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# Common options used for formatting markers are:
# * `markersize`
# * `markerfacecolor`
# * `markeredgecolor`

# %% [markdown]
# You can combine the use of lines and markers, and also plot the same data twice to get different colors:

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots( )
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( list1, list2, linewidth=1, color='black' )
ax.plot( list1, list2, linewidth=0, marker='o', markersize=7, color='green' ) # circle markers
ax.plot( list1, list3, linewidth=0, marker='s' ) # square markers

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# #### Legend

# %% [markdown]
# For each series of data in a plot, we can define a `label`, which we later include in a legend. Using the last graph, we can then define labels and include a legend as follows:

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots( figsize=(10,4) )
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( list1, list2, linewidth=1, color='black', label='list2-black' )
ax.plot( list1, list2, linewidth=0, marker='o', markersize=17, color='green', label='list2-green' )
ax.plot( list1, list3, linewidth=0, marker='s', label='list3' )

ax.legend( loc='best', title="Measuring sites 2020", fontsize=10 ) # Takes the 'labels' from each data series and displays a legend
#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# Note that there are two entries for the list2 data. This comes from the two lines that plot that data. We can just define an empty label to those data that we don't want to be in the legend:

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( list1, list2, 
         linewidth=1, color='black',
         marker='o', markersize=7, markerfacecolor='green', 
         label='list2-green' )

ax.plot( list1, list3, linewidth=0, marker='s', label='list3' )

ax.legend()
#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# It is possible to move the legend to a fixed location using the following coordinates. Otherwise, it will be placed in the _best_ place, which means somewhere where there is no plot, or at least not very much.
#
#         ===============   =============
#         Location String   Location Code
#         ===============   =============
#         'best'            0
#         'upper right'     1
#         'upper left'      2
#         'lower left'      3
#         'lower right'     4
#         'right'           5
#         'center left'     6
#         'center right'    7
#         'lower center'    8
#         'upper center'    9
#         'center'          10
#         ===============   =============
#
# For example, to manually place the legend in the center, use: `ax.legend( loc='center' )`

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( list1, list2, linewidth=1, color='black', label='' )
ax.plot( list1, list2, linewidth=0, marker='o', markersize=7, color='green', label='list2-green' )
ax.plot( list1, list3, linewidth=0, marker='s', label='list3' )

ax.legend( loc='center', title='Two series of data' )
#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# #### Axis labels and figure title

# %% [markdown]
# To add labels to the `x` and `y` axes we use: `ax.set_xlabel()` and `ax.set_xlabel()`.
#
# We can use formulas within the text with the "dollar-syntax": \\$2x+3/a\\$ → $2x+3/a$
#
# And we use `fontsize` to set, well, the font size.

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.

# Plot
ax.plot( list1, list2, linewidth=1, color='black', label='' )
ax.plot( list1, list2, linewidth=0, marker='o', markersize=7, color='green', label='list2-green' )
ax.plot( list1, list3, linewidth=0, marker='s', label='list3' )

# Format
ax.set_xlabel( 'Time $[s]$', fontsize=14 )
ax.set_ylabel( 'Acceleration $[ \mu m \cdot s^{-2}]$', fontsize=14 )
ax.legend( loc='best', title='Two series of data' )
ax.grid( ) # Add grid on both axes
fig.suptitle( 'Sup-title of the complete figure', fontsize=18 )

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# ### Predefined styles

# %% [markdown]
# `matplotlib` includes a number of formatting styles that can be used easily to change the overall looking of the graphs.
#
# A complete list of these styles can be consulted using the following command:

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# You can use these styles in two forms:
#
# * activate the style "permanently", and use it for the rest of the session or until you change it explicitly again
# * make only one single graph with a style and change again to the one that was previously active.

# %% [markdown]
# We can use this simple graph to test different styles. Having it wrapped in a function makes it easy to test.

# %%
def simple_graph():
    #---------------------------------------------------------------------
    # Part 1: Create a figure and axis using plt.subplots
    fig, ax = plt.subplots()
    #---------------------------------------------------------------------

    # Part 2: Plot, modify, plot again, include text, etc.

    # Plot
    ax.plot( list1, list2, linewidth=1, color='black', label='' )
    ax.plot( list1, list2, linewidth=0, marker='o', markersize=7, color='green', label='list2-green' )
    ax.plot( list1, list3, linewidth=0, marker='s', label='list3' )

    # Format
    ax.set_xlabel( 'Time $[s]$', fontsize=14 )
    ax.set_ylabel( 'Acceleration $[ m / s^2]$', fontsize=14 )
    ax.legend( loc='best', title='Two series of data' )
    ax.grid( ) # Add grid on both axes
    fig.suptitle( 'Sup-title of the complete figure', fontsize=18 )

    #---------------------------------------------------------------------
    # Part 3: Show, save to file, and close
    plt.show( fig ) 
    plt.close( fig ) 
    #---------------------------------------------------------------------

# %%
simple_graph()

# %% [markdown]
# To activate a style "permanently" use the following command:

# %%
plt.style.use( 'fivethirtyeight' ) # Set 'ggplot' as the plotting style from now on

# %% [markdown]
# Our simple graph now looks like:

# %%
simple_graph()

# %% [markdown]
# If you want to use a style only for one diagram, you wrap it in a `with` statement. After the execution, the style will revert to what was previously active.

# %%
with plt.style.context( 'dark_background' ):
    simple_graph()

# %%
plt.style.use( 'seaborn-ticks' )

# %%
simple_graph()

# %% [markdown]
# ## Examples.

# %% [markdown]
# ### Freshweight: Bar diagram

# %% [markdown]
# We will use the data from the lettuce experiment to create a simple bar diagram showing the average weight of the three treatments.
#
# For that, we use the `pandas` functionality to import the data, and also to create tables grouped by treatment.

# %%
import pandas as pd

# %% [markdown]
# We read the excel file 'lettuce.xlsx', and we need the data in the 'Freshweight' sheet:

# %%
df_freshweight = pd.read_excel( 'data/lettuce.xlsx', sheet_name='Freshweight' )
df_freshweight.head()
# Out:
#   Treatment  Tank  Plant  Freshweight (g)
# 0      Au47     1      2          363.755
# 1      Au47     1      3          233.540
# 2      Au47     1      5          368.570
# 3      Au47     1      7          336.960
# 4      Au47     1      8          357.880

# %% [markdown]
# Now, we group by treatment, using the mean as aggregation function. There are three treatments, we should therefore obtain 3 average results.

# %%
means = df_freshweight.groupby( by='Treatment' ).mean()

# %% [markdown]
# The function `groupby` will return the mean of all columns in the `df_freshweight` dataframe:

# %%
means
# Out:
#            Tank      Plant  Freshweight (g)
# Treatment
# Au47        3.0  12.960784       341.173824
# Au53        7.0  13.039216       354.654412
# Control     5.0  12.960784       360.300078

# %% [markdown]
# To create a bar diagram we use the same syntax from the previous diagrams, but we replace the function `ax.plot` by `ax.bar`:

# %%
colors = [ 'blue', 'yellow', 'black' ]

for i, item in enumerate( colors ):
    print( i, item, i )
# Out:
# 0 blue 0
# 1 yellow 1
# 2 black 2

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
individual_bars = ax.bar( means.index, means['Freshweight (g)'], width=0.4 )

colors = [ 'blue', 'yellow', 'black' ]

for i, bar in enumerate(individual_bars):
    individual_bars[i].set_color(colors[i])
    
individual_bars[0].set_color('blue')
individual_bars[1].set_color('yellow')
individual_bars[2].set_color('red')

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# A second element that is very easy to include in this diagram are error bars. There are error bars in x and in y. We need bars in the y-axis, and use therefore the `yerr` argument of the function.
#
# We need to pass this argument in either of two forms:
# * as a list of values, one for each bar: [ val1, val2, val3 ] → these will be the length of the error bars above and below the bars (this is the one we want to include with the corresponding standard deviation)
# * as a list of lists, 2 values for each bar: [ [ val1_below, val1_above ], [ val2_below, val2_above ], [ val3_below, val3_above ] ] → this would be needed to include maximum and minimum values, for example

# %% [markdown]
# To calculate the standard deviation we use the same syntax that with the means:

# %%
stds = df_freshweight.groupby( by='Treatment' ).std()

# %% [markdown]
# And we include that line in the `yerr` parameter. Remember to specify the column that we use: 'Freshweight (g)'.

# %%
stds['Freshweight (g)']
# Out:
# Treatment
# Au47       50.729054
# Au53       61.136323
# Control    36.067212
# Name: Freshweight (g), dtype: float64

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

manual_errors = [ 10, 100, 10 ]

# Part 2: Plot, modify, plot again, include text, etc.
ax.bar( means.index, means['Freshweight (g)'], width=0.4, yerr=manual_errors )

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# Lastly, we can supperpose a plot to the bars, for better presentation, and add labels to the x and y axes.

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots( )
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.bar( means.index, means['Freshweight (g)'], width=0.5, yerr=stds['Freshweight (g)'], color='red' )
ax.plot(means.index, means['Freshweight (g)'], marker='o', color='black', linewidth=0, markersize=15 )

ax.set_xlabel( 'Treatment', fontsize=14 )
ax.set_ylabel( 'Freshweight $[\mu g]$', fontsize=14 )
fig.suptitle( 'Lettuce freshweight', fontsize=16 )
#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# If you feel a little bit uneasy because the error bars don't have the upper and lower horizontal lines, caps, you can know that it is a feature of several styles, like `seaborn`. If you want to have more control over your error bars, you can use `ax.errorbar()`, instead of including it directly in the call to `ax.bar()`.
#
# Here an example of the use of errorbars:

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots( )
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.bar( means.index, means['Freshweight (g)'], width=0.5, color='red', linewidth=3, edgecolor='black' )
ax.errorbar( means.index, means['Freshweight (g)'], stds['Freshweight (g)'], color='black', capsize=7, markeredgewidth=2 )
ax.plot(means.index, means['Freshweight (g)'], marker='d', color='black', markersize=15 )

x_labels = [ 'Treatment 1', 'Treatment 2 - \n A very long treatment', 'Control' ]
ax.set_xticklabels( x_labels, fontsize=16, rotation=30, ha='right' )

ax.set_xlabel( 'Treatment', fontsize=14 )
ax.set_ylabel( 'Freshweight $[g]$', fontsize=14 )
fig.suptitle( 'Lettuce freshweight', fontsize=16 )
#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------
# Out:
# /tmp/ipykernel_400483/849789334.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels( x_labels, fontsize=16, rotation=30, ha='right' )

# %% [markdown]
# ### Air temperature: Dates and times

# %% [markdown]
# In this example we use the data in the csv file 'agroforst1.csv'.

# %% [markdown]
# We import the data to a new dataframe:

# %%
df_climate = pd.read_csv( 'data/agroforst1.csv', sep=';' )

# %%
df_climate.head()
# Out:
#                   Date  Temperature  Relative Humidity  Dew Point  Rain
# 0  2019-07-05 10:50:00        18.25              64.68      11.50   0.0
# 1  2019-07-05 10:55:00        18.27              64.12      11.39   0.0
# 2  2019-07-05 11:00:00        17.31              66.58      11.04   0.0
# 3  2019-07-05 11:05:00        16.96              68.21      11.08   0.0
# 4  2019-07-05 11:10:00        17.22              68.62      11.42   0.0

# %%
df_climate.tail()
# Out:
#                       Date  Temperature  Relative Humidity  Dew Point  Rain
# 19396  2019-09-11 23:20:00        16.02              63.59       9.13   0.0
# 19397  2019-09-11 23:25:00        16.30              62.20       9.07   0.0
# 19398  2019-09-11 23:30:00        16.36              62.61       9.23   0.0
# 19399  2019-09-11 23:35:00        16.04              64.15       9.28   0.0
# 19400  2019-09-11 23:40:00        15.87              65.25       9.37   0.0

# %%
df_climate.shape
# Out:
# (19401, 5)

# %% [markdown]
# To be able to work with dates and times, the dataframe needs to have a time-aware index:

# %%
df_climate.index = pd.DatetimeIndex( df_climate[ 'Date' ] )

# %%
df_climate
# Out:
#                                     Date  Temperature  Relative Humidity  \
# Date
# 2019-07-05 10:50:00  2019-07-05 10:50:00        18.25              64.68
# 2019-07-05 10:55:00  2019-07-05 10:55:00        18.27              64.12
# 2019-07-05 11:00:00  2019-07-05 11:00:00        17.31              66.58
# 2019-07-05 11:05:00  2019-07-05 11:05:00        16.96              68.21
# 2019-07-05 11:10:00  2019-07-05 11:10:00        17.22              68.62
# ...                                  ...          ...                ...
# 2019-09-11 23:20:00  2019-09-11 23:20:00        16.02              63.59
# 2019-09-11 23:25:00  2019-09-11 23:25:00        16.30              62.20
# 2019-09-11 23:30:00  2019-09-11 23:30:00        16.36              62.61
# 2019-09-11 23:35:00  2019-09-11 23:35:00        16.04              64.15
# 2019-09-11 23:40:00  2019-09-11 23:40:00        15.87              65.25
#
#                      Dew Point  Rain
# Date
# 2019-07-05 10:50:00      11.50   0.0
# ...

# %%
df_climate.index.min(), df_climate.index.max()
# Out:
# (Timestamp('2019-07-05 10:50:00'), Timestamp('2019-09-11 23:40:00'))

# %% [markdown]
# Let's pick a day and create a diagram of the temperature for that day only.
#
# We can start with the first day, April 18th 2018.

# %%
start = pd.Timestamp( '2019-08-04, 00:00:00' )
end = pd.Timestamp( '2019-08-05, 00:00:00' )

# %%
condition_start = df_climate.index >= start
condition_end = df_climate.index < end

one_day_only = df_climate[ condition_start & condition_end ]

# %%
# %matplotlib inline

# %%
one_day_only.shape
# Out:
# (285, 5)

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( one_day_only.index, one_day_only['Temperature'] )

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# There is one issue with the ticks in the x-axis: they show the complete date and time, making it sometimes illegible.
#
# To be able to format the x-axis with date and time values, we need to import the `dates` module from `matplotlib`:

# %%
from matplotlib import dates as mdates

# %% [markdown]
# The following two lines of code are very useful when working with dates and times.
#
# The first one will define the interval between ticks in the x-axis, in this case every 6 hours.
#
# The second line will format the ticks in the x-axis to have a certain format, in this case hours and minutes (without the date).

# %%
ax.xaxis.set_major_locator( mdates.HourLocator( byhour=range(0,24,6) ) )

ax.xaxis.set_major_formatter( mdates.DateFormatter('%H:%M') )

# %%
list( range(0,24,12) )

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( one_day_only.index, one_day_only['Temperature'] )

#Format axes
ax.xaxis.set_major_locator( mdates.HourLocator( byhour=range(0,24,12) ) )
ax.xaxis.set_major_formatter( mdates.DateFormatter('%d-%b \n %H:%M') ) 

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# Of course there are locators for dates also. We can check it with another example, using the data in the **rain** column and resampling to have the complete amount of precipitation per day:

# %%
daily_rain = df_climate[['Rain']].resample('1D').sum()

# %%
daily_rain.head()
# Out:
#             Rain
# Date
# 2019-07-05   0.0
# 2019-07-06   3.2
# 2019-07-07   0.0
# 2019-07-08   0.0
# 2019-07-09   0.0

# %%
daily_rain.index.min(), daily_rain.index.max()
# Out:
# (Timestamp('2019-07-05 00:00:00', freq='D'),
#  Timestamp('2019-09-11 00:00:00', freq='D'))

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( daily_rain.index, daily_rain['Rain'] )

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# We add now the first line below to locate the x ticks every 1st, 10th and 20th of the month.
#
# The second lines makes sure that the dates in the x-axis are in 'day-month' format.
#
# You can check the codes (note the %b for month) in [this link](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior).

# %%
ax.xaxis.set_major_locator( mdates.DayLocator( bymonthday=[1,10,20] ) )

ax.xaxis.set_major_formatter( mdates.DateFormatter('%d-%b') )

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
#ax.plot( daily_rain.index, daily_rain['Rain'] )
# More correctly as vertical lines:
ax.vlines( daily_rain.index, 0, daily_rain['Rain'], color='blue', linewidth=3 )

#Format axes
ax.xaxis.set_major_locator( mdates.DayLocator( bymonthday=[1,15] ) )
ax.xaxis.set_major_formatter( mdates.DateFormatter('%d-%b') ) 

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# ### Air temperature and relative humidity: Twin axes

# %% [markdown]
# So far, the diagrams have had a single x and a single y-axi1s. However, it is commonly needed to plot two series of data using different scales. In these cases, it is common to link one series to the left scale, and the other to the right.
#
# We can achieve this in `matplotlib` using the `twinx()` function.

# %% [markdown]
# We will build up on the temperature diagram from before, to include the relative humidity on the right-hand axis.
#
# The diagram was like this:

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( one_day_only.index, one_day_only['Temperature'] )

#Format axes
ax.xaxis.set_major_locator( mdates.HourLocator( byhour=range(0,24,5) ) )
ax.xaxis.set_major_formatter( mdates.DateFormatter('%d/%b \n %H:%M') ) 

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# If a second series of data is included, it will be drawn on the left-side axis (the only one, by that matter), resulting then in a problem with scale. In this case, temperature and relative humidity have values in different ranges, making it difficult to see the actual values on the curve:

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( one_day_only.index, one_day_only['Temperature'], color='red' )
ax.plot( one_day_only.index, one_day_only['Relative Humidity'], color='blue' )

#Format axes
ax.xaxis.set_major_locator( mdates.HourLocator( byhour=range(0,24,6) ) )
ax.xaxis.set_major_formatter( mdates.DateFormatter('%H:%M') ) 

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# To include a second axis, we take the existing one (`ax`) and create a second one as its 'twin'.
#
# We then use this second axis to plot, as we do with the first one. The data won't mix.
#
# The use of `twinx` should be understood as _they are twins, they share the same 'x'_.

# %%
ax_right = ax.twinx()

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
ax_right = ax.twinx()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( one_day_only.index, one_day_only['Temperature'], color='red' )

ax_right.plot( one_day_only.index, one_day_only['Relative Humidity'], color='blue' )

#Format axes
ax.xaxis.set_major_locator( mdates.HourLocator( byhour=range(0,24,3) ) )
ax.xaxis.set_major_formatter( mdates.DateFormatter('%H:%M') ) 

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
fig.tight_layout()
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# The function `fig.tight_layout()` often helps to give a slightly better distribution, particularly when there are different axes and legends.

# %% [markdown]
# There remains only giving some format to the graph:

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots( figsize=(9,6) )
ax_right = ax.twinx()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( one_day_only.index, one_day_only['Temperature'], color='red', label='Air temperature' )
ax.fill_between( one_day_only.index, 0, one_day_only['Temperature'], color='red', alpha=0.3 )

ax.plot( one_day_only.index[0], [0], color='blue', label='Relative humidity' ) # Trick: doesn't print anything, only used to get the legend

ax_right.plot( one_day_only.index, one_day_only['Relative Humidity'], color='blue', label='Relative humidity' )

#Format axes
ax.xaxis.set_major_locator( mdates.HourLocator( byhour=range(0,24,6) ) )
ax.xaxis.set_major_formatter( mdates.DateFormatter('%H:%M') ) 

ax.set_xlabel( 'Time', fontsize=14 )
ax.set_ylabel( 'Temperature $[^\circ C]$', fontsize=14 )
ax_right.set_ylabel( 'Relative humidity $[\%]$', fontsize=14 )

ax.set_ylim( [10,32] )
ax_right.set_ylim( [20,100] )

ax_right.grid( True )

ax.legend( loc='center left' )
#ax_right.legend( loc='top right' )

fig.suptitle( 'Air conditions at the agroforestry plot\n ' + str( start.date() ), fontsize=18 )

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
fig.tight_layout( rect=[0,0,1,0.99] )
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# ## Display modes: Interactive output, save to file.

# %% [markdown]
# Apart from showing the graphs in the screen, on your notebooks, you might be interested in:
# * showing them as interactive diagrams, to be able to zoom and move them
# * saving them as images to the disk, using PNG, PDF or other format

# %% [markdown]
# ### Interactive graphs

# %% [markdown]
# If you want to be able to zoom and move your graphs, include the following line in your notebook: `%matplotlib notebook`. You can include it at the very beginning, and it will work for the complete notebook. Note that sometimes there are problems if you want some graphs to be interactive and some to be static. If this happens to you, comment out the line with a `#` and run the notebook again. You can also use the command `%matplotlib inline` for static graphs.

# %%
# %matplotlib notebook

# %% [markdown]
# Now the same diagram with temperature and relative humidity behaves like this:

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots( figsize=(9,6) )
ax_right = ax.twinx()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( one_day_only.index, one_day_only['Temperature'], color='red', label='Air temperature' )
ax.plot( one_day_only.index[0], [0], color='blue', label='Relative humidity' ) # Trick: doesn't print anything, only used to get the legend

ax_right.plot( one_day_only.index, one_day_only['Relative Humidity'], color='blue', label='Relative humidity' )

#Format axes
ax.xaxis.set_major_locator( mdates.HourLocator( byhour=range(0,24,6) ) )
ax.xaxis.set_major_formatter( mdates.DateFormatter('%H:%M') ) 

ax.set_xlabel( 'Time', fontsize=14 )
ax.set_ylabel( 'Temperature $[^\circ C]$', fontsize=14 )
ax_right.set_ylabel( 'Relative humidity $[\%]$', fontsize=14 )

ax.set_ylim( [10,32] )
ax_right.set_ylim( [20,100] )

ax_right.grid( False )

ax.legend( loc='center left' )
#ax_right.legend( loc='top right' )

fig.suptitle( 'Air conditions at the agroforestry plot\n ' + str( start.date() ), fontsize=18 )

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
fig.tight_layout( rect=[0,0,1,0.99] )
plt.show( fig ) 
#plt.close( fig )  ## ← Comment out this line for interactive graphs!!
#---------------------------------------------------------------------
# Out:
# <img src="data:image/png;base64,..." width="648">

# %% [markdown]
# NOTE: Comment out the line with `plt.close()` if you want interactive graphs!

# %%
fig, ax = plt.subplots()

ax.plot( df_climate.index, df_climate['Temperature'] )

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### Save to a file

# %%
# %matplotlib inline

# %% [markdown]
# This is the very first example in this notebook:

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( list3 )

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.show( fig ) 
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# The function `plt.savefig()` will save the active figure to the hard disk. We can specify the format and also the resolution of the file in dpi (dots per inch).
#
# NOTE: Use this function ___before___ `plt.show()` and `plt.close()`, or you won't get any output.

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( list3 )

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
plt.savefig( 'graph1.pdf', dpi=300 )
plt.show( fig )
plt.close( fig ) 
#---------------------------------------------------------------------

# %% [markdown]
# If you want to check which file formats are available, run the following command:

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# The graph of temperature and relative humidity can then be saved like this:

# %%
#---------------------------------------------------------------------
# Part 1: Create a figure and axis using plt.subplots
fig, ax = plt.subplots( figsize=(9,6) )
ax_right = ax.twinx()
#---------------------------------------------------------------------

# Part 2: Plot, modify, plot again, include text, etc.
ax.plot( one_day_only.index, one_day_only['Temperature'], color='red', label='Air temperature' )
ax.plot( one_day_only.index[0], [0], color='blue', label='Relative humidity' ) # Trick: doesn't print anything, only used to get the legend

ax_right.plot( one_day_only.index, one_day_only['Relative Humidity'], color='blue', label='Relative humidity' )

#Format axes
ax.xaxis.set_major_locator( mdates.HourLocator( byhour=range(0,24,6) ) )
ax.xaxis.set_major_formatter( mdates.DateFormatter('%H:%M') ) 

ax.set_xlabel( 'Time', fontsize=14 )
ax.set_ylabel( 'Temperature $[^\circ C]$', fontsize=14 )
ax_right.set_ylabel( 'Relative humidity $[\%]$', fontsize=14 )

ax.set_ylim( [10,32] )
ax_right.set_ylim( [20,100] )

ax_right.grid( False )

ax.legend( loc='center left' )
#ax_right.legend( loc='top right' )

fig.suptitle( 'Air conditions at the agroforestry plot\n ' + str( start.date() ), fontsize=18 )

#---------------------------------------------------------------------
# Part 3: Show, save to file, and close
fig.tight_layout( rect=[0,0,1,0.99] )
plt.savefig( 'temp-rh.pdf', dpi=300 )
plt.show( fig ) 
plt.close( fig )
#---------------------------------------------------------------------

# %% [markdown]
# Last note: If you have a very heavy plot, you might want to plot it to a file directly, without rendering it to the screen. This can be particularly useful in two situations:
# * when you want to make lots of graphs (in a `for` loop) and save them all to the disk, without showing them in screen
# * when you are using a not-so-powerful computer and would like to save memory
#
# In these cases, just comment out (or delete) the `plt.show()` line. You will get your file in the disk, without seeing it on the screen.

# %% [markdown]
# ## Links

# %% [markdown]
# [Matplotlib gallery](https://matplotlib.org/gallery/index.html)
#
# [Matplotlib examples](https://matplotlib.org/examples/index.html)
#
# [Codes for time formats](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior)
#
# [Official cheatsheets](https://github.com/matplotlib/cheatsheets)

# %% [markdown]
# ___
